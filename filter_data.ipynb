# %%
# filter/clean up data frame and write into filtered.csv
import pandas as pd
df = pd.read_csv('innocence_project_stats.csv')
col_names = list(df)
col_names
# Out:
# ['Last Name',
#  'First Name',
#  'Age',
#  'Race',
#  'ST',
#  'County of Crime',
#  'Tags',
#  'OM Tags',
#  'Crime',
#  'Sentence',
#  'Convicted',
#  'Exonerated',
#  'DNA',
#  'MWID',
#  'FC',
#  'P/FA',
#  'F/MFE',
#  'OM',
#  'ILD']

# %%
# reorder and drop columns
df = df[['Last Name', 'First Name', 'Age', 'Race', 'Crime', 'Sentence', 'Convicted', 'Exonerated', 'DNA', "ST"]]
print(list(df))
# Out:
# ['Last Name', 'First Name', 'Age', 'Race', 'Crime', 'Sentence', 'Convicted', 'Exonerated', 'DNA', 'ST']

# %%
# make 1 column for Name and remove the 2 name columns

df['Name'] = df.insert(0, 'Name', None)
df["Name"] = df["First Name"] + " " + df["Last Name"]
df = df.drop(columns=["First Name", "Last Name"])
df
# Out:
#                        Name   Age   Race                    Crime  \
# 0             Joseph Abbitt  31.0  Black          Child Sex Abuse
# 1             Cinque Abbott  19.0  Black  Drug Possession or Sale
# 2        Warith Habib Abdal  43.0  Black           Sexual Assault
# 3     Christopher Abernathy  17.0  White                   Murder
# 4             Quentin Abney  32.0  Black                  Robbery
# ...                     ...   ...    ...                      ...
# 3321        Richard Zawacki  38.0  White          Child Sex Abuse
# 3322          Walter Zimmer  40.0  White             Manslaughter
# 3323         Evan Zimmerman  53.0  White                   Murder
# 3324      Tyrone Zinkiewicz  38.0  White  Other Nonviolent Felony
# 3325         Michael Zomber  53.0  White                    Fraud
#
#                   Sentence  Convicted  Exonerated  DNA    ST
# 0                     Life       1995        2009  DNA    NC
# 1                Probation       2008        2022  NaN    IL
# 2               20 to Life       1983        1999  DNA    NY
# 3      Life without parole       1987        2015  DNA    IL
# 4               20 to Life       2006        2012  NaN    NY
# ...                    ...        ...         ...  ...   ...
# 3321               4 years       2000        2001  NaN    IN
# 3322              50 years       1998        2011  DNA    OH
# 3323                  Life       2001        2005  DNA    WI
# 3324         5 to 15 years       1988        1992  NaN    OH
# 3325  2 years and 6 months       2003        2009  NaN  F-PA
#
# [3326 rows x 9 columns]

# %%
# make Age an int value (why float?)
df["Age"] = df["Age"].astype("Int8")

# %%
# Flag those with sentences containing Life

# new column for Life sentences (True/False)
df['Life'] = df.insert(5, 'Life', None)
print(list(df))
# Out:
# ['Name', 'Age', 'Race', 'Crime', 'Sentence', 'Life', 'Convicted', 'Exonerated', 'DNA', 'ST']

# %%
df[df["ST"] == "L"]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Race, Crime, Sentence, Life, Convicted, Exonerated, DNA, ST]
# Index: []

# %%
for i,row in df.iterrows(): 
    #print (i, list(row))  # DEBUG: row has values for the row with the index i
    s = row["Sentence"] # sentence
    if 'life' in s.lower():
        df.loc[i, "Life"] = True   
    else:
        df.loc[i, "Life"] = False

df
# Out:
#                        Name  Age   Race                    Crime  \
# 0             Joseph Abbitt   31  Black          Child Sex Abuse
# 1             Cinque Abbott   19  Black  Drug Possession or Sale
# 2        Warith Habib Abdal   43  Black           Sexual Assault
# 3     Christopher Abernathy   17  White                   Murder
# 4             Quentin Abney   32  Black                  Robbery
# ...                     ...  ...    ...                      ...
# 3321        Richard Zawacki   38  White          Child Sex Abuse
# 3322          Walter Zimmer   40  White             Manslaughter
# 3323         Evan Zimmerman   53  White                   Murder
# 3324      Tyrone Zinkiewicz   38  White  Other Nonviolent Felony
# 3325         Michael Zomber   53  White                    Fraud
#
#                   Sentence   Life  Convicted  Exonerated  DNA    ST
# 0                     Life   True       1995        2009  DNA    NC
# 1                Probation  False       2008        2022  NaN    IL
# 2               20 to Life   True       1983        1999  DNA    NY
# 3      Life without parole   True       1987        2015  DNA    IL
# 4               20 to Life   True       2006        2012  NaN    NY
# ...                    ...    ...        ...         ...  ...   ...
# 3321               4 years  False       2000        2001  NaN    IN
# 3322              50 years  False       1998        2011  DNA    OH
# 3323                  Life   True       2001        2005  DNA    WI
# 3324         5 to 15 years  False       1988        1992  NaN    OH
# 3325  2 years and 6 months  False       2003        2009  NaN  F-PA
#
# [3326 rows x 10 columns]

# %%
# drop those with Life == "False"
df = df.drop(df[df["Life"] == False].index)
df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 2        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 3     Christopher Abernathy   17  White           Murder  Life without parole
# 4             Quentin Abney   32  Black          Robbery           20 to Life
# 11            Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 3306       Anthony Yarbough   18  Black           Murder           75 to life
# 3310           Kenneth York   38  White   Sexual Assault  Life without parole
# 3313             Paul Young   17  Black           Murder  Life without parole
# 3314         Dan Young, Jr.   30  Black           Murder  Life without parole
# 3323         Evan Zimmerman   53  White           Murder                 Life
#
#       Life  Convicted  Exonerated  DNA  ST
# 0     True       1995        2009  DNA  NC
# 2     True       1983        1999  DNA  NY
# 3     True       1987        2015  DNA  IL
# 4     True       2006        2012  NaN  NY
# 11    True       1992        2011  NaN  PA
# ...    ...        ...         ...  ...  ..
# 3306  True       1994        2014  DNA  NY
# 3310  True       1994        2010  DNA  MO
# 3313  True       1987        2021  NaN  MI
# 3314  True       1994        2005  DNA  IL
# 3323  True       2001        2005  DNA  WI
#
# [1028 rows x 10 columns]

# %%
# Now also drop Life column as it's no longer needed
df = df.drop("Life", axis=1)

# %%
# drop entries w/o state entries
df = df.drop(df[df["ST"] == ""].index)

# substitute all the F- states
for i,row in df.iterrows(): 
    #print (i, list(row))  # DEBUG: row has values for the row with the index i
    s = row["ST"] # 
    if s[0:2] == "F-":
        df.loc[i, "ST"] = s[4:] 

df["ST"].unique()
# Out:
# array(['NC', 'NY', 'IL', 'PA', 'LA', 'CT', 'CA', 'OH', 'MS', 'TX', 'WA',
#        'WI', 'MO', 'VA', 'MI', 'RI', 'OK', 'MD', 'TN', 'FL', 'NJ', 'MA',
#        'WV', 'SC', 'NV', 'KS', 'OR', 'AR', 'UT', 'GA', 'MT', 'DC', 'IN',
#        'PR', 'KY', 'AL', 'DE', 'CO', 'WY', 'NM', 'IA', 'AZ', 'VT', 'NE',
#        'HI', 'ID'], dtype=object)

# %%
# add a new column with duration (Exonerated - Convicted)
df['Duration'] = df.insert(5, 'Duration', 0)
df["Duration"] = df["Exonerated"] - df["Convicted"]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\charding\Box\HCI584\student_code\State_murderHCI584\filter_data.ipynb Cell 11 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/charding/Box/HCI584/student_code/State_murderHCI584/filter_data.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> # add a new column with duration (Exonerated - Convicted)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/charding/Box/HCI584/student_code/State_murderHCI584/filter_data.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> df['Duration'] = df.insert(5, 'Duration', 0)
#       <a href='vscode-notebook-cell:/c%3A/Users/charding/Box/HCI584/student_code/State_murderHCI584/filter_data.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a> df["Duration"] = df["Exonerated"] - df["Convicted"]
#       <a href='vscode-notebook-cell:/c%3A/Users/charding/Box/HCI584/student_code/State_murderHCI584/filter_data.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a> df
#
# File c:\Users\charding\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:4440, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4434     raise ValueError(
#    4435         "Cannot specify 'allow_duplicates=True' when "
#    4436         "'self.flags.allows_duplicate_labels' is False."
#    4437     )
#    4438 if not allow_duplicates and column in self.columns:
#    4439     # Should this be a different kind of error??
# -> 4440     raise ValueError(f"cannot insert {column}, already exists")
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
#
# ValueError: cannot insert Duration, already exists

# %%
# For DNA use True and False, not DNA and NaN 
for i,row in df.iterrows(): 
    #print (i, list(row))  # DEBUG: row has values for the row with the index i
    if row["DNA"] == "DNA":
        df.loc[i, "DNA"] = True   # short for  blue
    else:
        df.loc[i, "DNA"] = False
df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 2        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 3     Christopher Abernathy   17  White           Murder  Life without parole
# 4             Quentin Abney   32  Black          Robbery           20 to Life
# 11            Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 3306       Anthony Yarbough   18  Black           Murder           75 to life
# 3310           Kenneth York   38  White   Sexual Assault  Life without parole
# 3313             Paul Young   17  Black           Murder  Life without parole
# 3314         Dan Young, Jr.   30  Black           Murder  Life without parole
# 3323         Evan Zimmerman   53  White           Murder                 Life
#
#       Duration  Convicted  Exonerated    DNA  ST
# 0           14       1995        2009   True  NC
# 2           16       1983        1999   True  NY
# 3           28       1987        2015   True  IL
# 4            6       2006        2012  False  NY
# 11          19       1992        2011  False  PA
# ...        ...        ...         ...    ...  ..
# 3306        20       1994        2014   True  NY
# 3310        16       1994        2010   True  MO
# 3313        34       1987        2021  False  MI
# 3314        11       1994        2005   True  IL
# 3323         4       2001        2005   True  WI
#
# [1028 rows x 10 columns]

# %%
# re-build a 0 to N continuous index
df = df.reset_index(drop=True)
df.index.name = "#"
df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# #
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 1        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 2     Christopher Abernathy   17  White           Murder  Life without parole
# 3             Quentin Abney   32  Black          Robbery           20 to Life
# 4             Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 1018       Anthony Yarbough   18  Black           Murder           75 to life
# 1019           Kenneth York   38  White   Sexual Assault  Life without parole
# 1020             Paul Young   17  Black           Murder  Life without parole
# 1021         Dan Young, Jr.   30  Black           Murder  Life without parole
# 1022         Evan Zimmerman   53  White           Murder                 Life
#
#       Duration  Convicted  Exonerated    DNA  ST
# #
# 0           14       1995        2009   True  NC
# 1           16       1983        1999   True  NY
# 2           28       1987        2015   True  IL
# 3            6       2006        2012  False  NY
# 4           19       1992        2011  False  PA
# ...        ...        ...         ...    ...  ..
# 1018        20       1994        2014   True  NY
# 1019        16       1994        2010   True  MO
# 1020        34       1987        2021  False  MI
# 1021        11       1994        2005   True  IL
# 1022         4       2001        2005   True  WI
#
# [1023 rows x 10 columns]

# %%
# Save to new file
df.to_csv("filtered.csv")

# %%
# Aggregate (group) by ST:  

# https://pandas.pydata.org/pandas-docs/stable/getting_started/intro_tutorials/06_calculate_statistics.html#aggregating-statistics-grouped-by-category

# note that ST will be the index
ST_count = df[["ST","Name"]].groupby("ST").count()
ST_count = ST_count.rename(columns={"Name": "Count"})

ST_durantion_mean = df[["ST","Duration"]].groupby("ST").mean().round(1)
# more

# make dataframe from above
ST_df = pd.concat([ST_count,ST_durantion_mean], axis=1)
ST_df
# Out:
#     Count  Duration
# ST
# AL      9      10.1
# AR      5      15.4
# AZ      1       9.0
# CA    123      14.2
# CO      6       8.5
# CT      4      17.2
# DC     13      29.3
# DE      1      38.0
# FL     33      17.6
# GA     32      15.5
# HI      1      23.0
# IA      4      16.0
# ID      2      18.5
# IL     64      20.5
# IN      2       7.5
# KS      6      14.8
# KY      5      22.6
# LA     54      20.9
# MA     40      23.7
# MD     25      19.5
# MI     56      18.4
# MO     27      13.9
# MS     10      15.9
# MT      2      16.5
# NC     27      19.1
# NE      2      27.0
# NJ     14      18.0
# NM      4      13.2
# NV     10      18.6
# NY    159      18.1
# OH     39      15.5
# OK     17      11.7
# OR      9       6.4
# PA     65      17.2
# PR      4      16.8
# RI      2       5.0
# SC      5      12.0
# TN     13      16.5
# TX     64      16.3
# UT     14       7.4
# VA     17      20.2
# VT      1      18.0
# WA      6      12.8
# WI     16      13.6
# WV      7      12.0
# WY      3       9.3

# %%
# Run the graphing app inside jupyter

# Import packages
from dash import Dash, html, dash_table, dcc, callback, Output, Input
import pandas as pd
import plotly.express as px

# Incorporate data
df = pd.read_csv('filtered.csv')
num_rows = len(df)

# Initialize the app
app = Dash(__name__)

# App layout
app.layout = html.Div([
    html.Div(children=f'Total of {num_rows} entries, select a Histogram ',  style={'color': 'Gold', 'font-size': 20}),
    html.Hr(),

    # CH: value must be an existing column, you had lifeExp which is not a valid column name
    dcc.RadioItems(options=['Race', 'Crime', 'ST', 'Age', 'Duration', 'DNA' ], value='Race', 
                   inline=True, 
                   id='controls-and-radio-item',
                   style={'color': 'Gold', 'font-size': 20}),
    dcc.Graph(figure={}, id='controls-and-graph')
])

# Add controls to build the interaction
@callback(
    Output(component_id='controls-and-graph', component_property='figure'),
    Input(component_id='controls-and-radio-item', component_property='value')
)


def update_graph(col_chosen):
    fig = px.histogram(df, x=col_chosen)
    return fig

def updateTable(n):
     pass

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
