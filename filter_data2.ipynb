# %%
# filter/clean up data frame and write into filtered.csv
import pandas as pd
df = pd.read_csv('innocence_project_stats.csv')
col_names = list(df)
col_names
# Out:
# ['LastName',
#  'FirstName',
#  'Age',
#  'Race',
#  'ST',
#  'County',
#  'Tags',
#  'OM_Tags',
#  'Crime',
#  'Sentence',
#  'Convicted',
#  'Exonerated',
#  'DNA',
#  'MWID',
#  'FC',
#  'P_FA',
#  'F_MFE',
#  'OM',
#  'ILD']

# %%
# reorder and drop columns
df = df[['LastName', 'FirstName', 'Age', 'Race', 'Crime', 'Sentence', 'Convicted', 'Exonerated', 'DNA', "ST", "County"]]
print(list(df))
# Out:
# ['LastName', 'FirstName', 'Age', 'Race', 'Crime', 'Sentence', 'Convicted', 'Exonerated', 'DNA', 'ST', 'County']

# %%
# make 1 column for Name and remove the 2 name columns

df['Name'] = df.insert(0, 'Name', None)
df["Name"] = df["FirstName"] + " " + df["LastName"]
df = df.drop(columns=["FirstName", "LastName"])
df
# Out:
#                        Name   Age   Race                    Crime  \
# 0             Joseph Abbitt  31.0  Black          Child Sex Abuse
# 1             Cinque Abbott  19.0  Black  Drug Possession or Sale
# 2        Warith Habib Abdal  43.0  Black           Sexual Assault
# 3     Christopher Abernathy  17.0  White                   Murder
# 4             Quentin Abney  32.0  Black                  Robbery
# ...                     ...   ...    ...                      ...
# 3321        Richard Zawacki  38.0  White          Child Sex Abuse
# 3322          Walter Zimmer  40.0  White             Manslaughter
# 3323         Evan Zimmerman  53.0  White                   Murder
# 3324      Tyrone Zinkiewicz  38.0  White  Other Nonviolent Felony
# 3325         Michael Zomber  53.0  White                    Fraud
#
#                   Sentence  Convicted  Exonerated  DNA    ST      County
# 0                     Life       1995        2009  DNA    NC     Forsyth
# 1                Probation       2008        2022  NaN    IL        Cook
# 2               20 to Life       1983        1999  DNA    NY        Erie
# 3      Life without parole       1987        2015  DNA    IL        Cook
# 4               20 to Life       2006        2012  NaN    NY    New York
# ...                    ...        ...         ...  ...   ...         ...
# 3321               4 years       2000        2001  NaN    IN  Huntington
# 3322              50 years       1998        2011  DNA    OH    Cuyahoga
# 3323                  Life       2001        2005  DNA    WI  Eau Claire
# 3324         5 to 15 years       1988        1992  NaN    OH  Montgomery
# 3325  2 years and 6 months       2003        2009  NaN  F-PA   (Eastern)
#
# [3326 rows x 10 columns]

# %%
# make Age an int value (why float?)
df["Age"] = df["Age"].astype("Int8")

# %%
# Flag those with sentences containing Life

# new column for Life sentences (True/False)
df['Life'] = df.insert(5, 'Life', None)
print(list(df))
# Out:
# ['Name', 'Age', 'Race', 'Crime', 'Sentence', 'Life', 'Convicted', 'Exonerated', 'DNA', 'ST', 'County']

# %%
for i,row in df.iterrows(): 
    #print (i, list(row))  # DEBUG: row has values for the row with the index i
    s = row["Sentence"] # sentence
    if 'life' in s.lower():
        df.loc[i, "Life"] = True   
    else:
        df.loc[i, "Life"] = False

df
# Out:
#                        Name  Age   Race                    Crime  \
# 0             Joseph Abbitt   31  Black          Child Sex Abuse
# 1             Cinque Abbott   19  Black  Drug Possession or Sale
# 2        Warith Habib Abdal   43  Black           Sexual Assault
# 3     Christopher Abernathy   17  White                   Murder
# 4             Quentin Abney   32  Black                  Robbery
# ...                     ...  ...    ...                      ...
# 3321        Richard Zawacki   38  White          Child Sex Abuse
# 3322          Walter Zimmer   40  White             Manslaughter
# 3323         Evan Zimmerman   53  White                   Murder
# 3324      Tyrone Zinkiewicz   38  White  Other Nonviolent Felony
# 3325         Michael Zomber   53  White                    Fraud
#
#                   Sentence   Life  Convicted  Exonerated  DNA    ST  \
# 0                     Life   True       1995        2009  DNA    NC
# 1                Probation  False       2008        2022  NaN    IL
# 2               20 to Life   True       1983        1999  DNA    NY
# 3      Life without parole   True       1987        2015  DNA    IL
# 4               20 to Life   True       2006        2012  NaN    NY
# ...                    ...    ...        ...         ...  ...   ...
# 3321               4 years  False       2000        2001  NaN    IN
# 3322              50 years  False       1998        2011  DNA    OH
# 3323                  Life   True       2001        2005  DNA    WI
# 3324         5 to 15 years  False       1988        1992  NaN    OH
# 3325  2 years and 6 months  False       2003        2009  NaN  F-PA
#
#           County
# 0        Forsyth
# 1           Cook
# 2           Erie
# 3           Cook
# 4       New York
# ...          ...
# 3321  Huntington
# 3322    Cuyahoga
# 3323  Eau Claire
# 3324  Montgomery
# 3325   (Eastern)
#
# [3326 rows x 11 columns]

# %%
# drop those with Life == "False"
df = df.drop(df[df["Life"] == False].index)
df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 2        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 3     Christopher Abernathy   17  White           Murder  Life without parole
# 4             Quentin Abney   32  Black          Robbery           20 to Life
# 11            Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 3306       Anthony Yarbough   18  Black           Murder           75 to life
# 3310           Kenneth York   38  White   Sexual Assault  Life without parole
# 3313             Paul Young   17  Black           Murder  Life without parole
# 3314         Dan Young, Jr.   30  Black           Murder  Life without parole
# 3323         Evan Zimmerman   53  White           Murder                 Life
#
#       Life  Convicted  Exonerated  DNA  ST        County
# 0     True       1995        2009  DNA  NC       Forsyth
# 2     True       1983        1999  DNA  NY          Erie
# 3     True       1987        2015  DNA  IL          Cook
# 4     True       2006        2012  NaN  NY      New York
# 11    True       1992        2011  NaN  PA  Philadelphia
# ...    ...        ...         ...  ...  ..           ...
# 3306  True       1994        2014  DNA  NY         Kings
# 3310  True       1994        2010  DNA  MO        Vernon
# 3313  True       1987        2021  NaN  MI         Wayne
# 3314  True       1994        2005  DNA  IL          Cook
# 3323  True       2001        2005  DNA  WI    Eau Claire
#
# [1028 rows x 11 columns]

# %%
# Now also drop Life column as it's no longer needed
df = df.drop("Life", axis=1)

# %%
# add a new column with duration (Exonerated - Convicted)
df['Duration'] = df.insert(5, 'Duration', 0)
df["Duration"] = df["Exonerated"] - df["Convicted"]
df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 2        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 3     Christopher Abernathy   17  White           Murder  Life without parole
# 4             Quentin Abney   32  Black          Robbery           20 to Life
# 11            Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 3306       Anthony Yarbough   18  Black           Murder           75 to life
# 3310           Kenneth York   38  White   Sexual Assault  Life without parole
# 3313             Paul Young   17  Black           Murder  Life without parole
# 3314         Dan Young, Jr.   30  Black           Murder  Life without parole
# 3323         Evan Zimmerman   53  White           Murder                 Life
#
#       Duration  Convicted  Exonerated  DNA  ST        County
# 0           14       1995        2009  DNA  NC       Forsyth
# 2           16       1983        1999  DNA  NY          Erie
# 3           28       1987        2015  DNA  IL          Cook
# 4            6       2006        2012  NaN  NY      New York
# 11          19       1992        2011  NaN  PA  Philadelphia
# ...        ...        ...         ...  ...  ..           ...
# 3306        20       1994        2014  DNA  NY         Kings
# 3310        16       1994        2010  DNA  MO        Vernon
# 3313        34       1987        2021  NaN  MI         Wayne
# 3314        11       1994        2005  DNA  IL          Cook
# 3323         4       2001        2005  DNA  WI    Eau Claire
#
# [1028 rows x 11 columns]

# %%
# For DNA use True and False, not DNA and NaN 
for i,row in df.iterrows(): 
    #print (i, list(row))  # DEBUG: row has values for the row with the index i
    if row["DNA"] == "DNA":
        df.loc[i, "DNA"] = True   # short for  blue
    else:
        df.loc[i, "DNA"] = False
df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 2        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 3     Christopher Abernathy   17  White           Murder  Life without parole
# 4             Quentin Abney   32  Black          Robbery           20 to Life
# 11            Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 3306       Anthony Yarbough   18  Black           Murder           75 to life
# 3310           Kenneth York   38  White   Sexual Assault  Life without parole
# 3313             Paul Young   17  Black           Murder  Life without parole
# 3314         Dan Young, Jr.   30  Black           Murder  Life without parole
# 3323         Evan Zimmerman   53  White           Murder                 Life
#
#       Duration  Convicted  Exonerated    DNA  ST        County
# 0           14       1995        2009   True  NC       Forsyth
# 2           16       1983        1999   True  NY          Erie
# 3           28       1987        2015   True  IL          Cook
# 4            6       2006        2012  False  NY      New York
# 11          19       1992        2011  False  PA  Philadelphia
# ...        ...        ...         ...    ...  ..           ...
# 3306        20       1994        2014   True  NY         Kings
# 3310        16       1994        2010   True  MO        Vernon
# 3313        34       1987        2021  False  MI         Wayne
# 3314        11       1994        2005   True  IL          Cook
# 3323         4       2001        2005   True  WI    Eau Claire
#
# [1028 rows x 11 columns]

# %%
#add median age
age_med = df['Age'].median()

print(age_med)
# Out:
# 24.0

# %%
#State with most exonerations
from collections import Counter
data = Counter(df['ST'])
AllStates = data.most_common()   # Returns all unique items and their counts
Most_State = data.most_common(1)  # Returns the highest occurring item
print(Most_State)
# Out:
# [('NY', 159)]

# %%
#Use same method to find largest racial group
data = Counter(df['Race'])
Race_Counts = data.most_common()
Most_Race = data.most_common(1)  # Returns all unique items and their counts
print("The largest Racial group is:", Most_Race)  # Returns the highest occurring item
# Out:
# The largest Racial group is: [('Black', 586)]

# %%
#Find the most common crime

data = Counter(df['Crime'])
Most_Crimes = data.most_common()   # Returns all unique items and their counts
Most_Crimes1 = data.most_common(1)  # Returns the highest occurring item
print(Most_Crimes1)
# Out:
# [('Murder', 798)]

# %%
#Create List of names for each state

#I need to match states with names 

ST_List= []

# %%
# re-build a 0 to N continuous index
df = df.reset_index(drop=True)
df.index.name = "#"
df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# #
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 1        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 2     Christopher Abernathy   17  White           Murder  Life without parole
# 3             Quentin Abney   32  Black          Robbery           20 to Life
# 4             Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 1023       Anthony Yarbough   18  Black           Murder           75 to life
# 1024           Kenneth York   38  White   Sexual Assault  Life without parole
# 1025             Paul Young   17  Black           Murder  Life without parole
# 1026         Dan Young, Jr.   30  Black           Murder  Life without parole
# 1027         Evan Zimmerman   53  White           Murder                 Life
#
#       Duration  Convicted  Exonerated    DNA  ST        County
# #
# 0           14       1995        2009   True  NC       Forsyth
# 1           16       1983        1999   True  NY          Erie
# 2           28       1987        2015   True  IL          Cook
# 3            6       2006        2012  False  NY      New York
# 4           19       1992        2011  False  PA  Philadelphia
# ...        ...        ...         ...    ...  ..           ...
# 1023        20       1994        2014   True  NY         Kings
# 1024        16       1994        2010   True  MO        Vernon
# 1025        34       1987        2021  False  MI         Wayne
# 1026        11       1994        2005   True  IL          Cook
# 1027         4       2001        2005   True  WI    Eau Claire
#
# [1028 rows x 11 columns]

# %%
# Save to new file
df.to_csv("filtered.csv")

# %%
# append lat/long of country


# read in US counties DB
df_counties = pd.read_csv("uscounties.csv")
display(df_counties.head(5))

# state controid coordinates, used if the county lookup doesn't work
df_states = pd.read_csv("state.csv")
df_states.head(5)
# Out:
#         county county_ascii         county_full  county_fips state_id  \
# 0  Los Angeles  Los Angeles  Los Angeles County         6037       CA
# 1         Cook         Cook         Cook County        17031       IL
# 2       Harris       Harris       Harris County        48201       TX
# 3     Maricopa     Maricopa     Maricopa County         4013       AZ
# 4    San Diego    San Diego    San Diego County         6073       CA
#
#    state_name      lat       lng  population
# 0  California  34.3209 -118.2247    10019635
# 1    Illinois  41.8401  -87.8168     5265398
# 2       Texas  29.8577  -95.3936     4697957
# 3     Arizona  33.3490 -112.4915     4367186
# 4  California  33.0343 -116.7350     3296317
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[17], line 9
#       6 display(df_counties.head(5))
#       8 # state controid coordinates, used if the county lookup doesn't work
# ----> 9 df_states = pd.read_csv("state.csv")
#      10 df_states.head(5)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:950, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     946     defaults={"delimiter": ","},
#     947 )
#     948 kwds.update(kwds_defaults)
# --> 950 return _read(filepath_or_buffer, kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:605, in _read(filepath_or_buffer, kwds)
#     602 _validate_names(kwds.get("names", None))
#     604 # Create the parser.
# --> 605 parser = TextFileReader(filepath_or_buffer, **kwds)
#     607 if chunksize or iterator:
#     608     return parser
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1442, in TextFileReader.__init__(self, f, engine, **kwds)
#    1439     self.options["has_index_names"] = kwds["has_index_names"]
#    1441 self.handles: IOHandles | None = None
# -> 1442 self._engine = self._make_engine(f, self.engine)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/parsers/readers.py:1735, in TextFileReader._make_engine(self, f, engine)
#    1733     if "b" not in mode:
#    1734         mode += "b"
# -> 1735 self.handles = get_handle(
#    1736     f,
#    1737     mode,
#    1738     encoding=self.options.get("encoding", None),
#    1739     compression=self.options.get("compression", None),
#    1740     memory_map=self.options.get("memory_map", False),
#    1741     is_text=is_text,
#    1742     errors=self.options.get("encoding_errors", "strict"),
#    1743     storage_options=self.options.get("storage_options", None),
#    1744 )
#    1745 assert self.handles is not None
#    1746 f = self.handles.handle
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/io/common.py:856, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     851 elif isinstance(handle, str):
#     852     # Check whether the filename is to be opened in binary mode.
#     853     # Binary mode does not support 'encoding' and 'newline'.
#     854     if ioargs.encoding and "b" not in ioargs.mode:
#     855         # Encoding
# --> 856         handle = open(
#     857             handle,
#     858             ioargs.mode,
#     859             encoding=ioargs.encoding,
#     860             errors=errors,
#     861             newline="",
#     862         )
#     863     else:
#     864         # Binary mode
#     865         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'state.csv'

# %%
# add 2 columns for lat and long (init wth None)
df["Lat"] = None
df["Long"] = None
df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# #
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 1        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 2     Christopher Abernathy   17  White           Murder  Life without parole
# 3             Quentin Abney   32  Black          Robbery           20 to Life
# 4             Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 1023       Anthony Yarbough   18  Black           Murder           75 to life
# 1024           Kenneth York   38  White   Sexual Assault  Life without parole
# 1025             Paul Young   17  Black           Murder  Life without parole
# 1026         Dan Young, Jr.   30  Black           Murder  Life without parole
# 1027         Evan Zimmerman   53  White           Murder                 Life
#
#       Duration  Convicted  Exonerated    DNA  ST        County   Lat  Long
# #
# 0           14       1995        2009   True  NC       Forsyth  None  None
# 1           16       1983        1999   True  NY          Erie  None  None
# 2           28       1987        2015   True  IL          Cook  None  None
# 3            6       2006        2012  False  NY      New York  None  None
# 4           19       1992        2011  False  PA  Philadelphia  None  None
# ...        ...        ...         ...    ...  ..           ...   ...   ...
# 1023        20       1994        2014   True  NY         Kings  None  None
# 1024        16       1994        2010   True  MO        Vernon  None  None
# 1025        34       1987        2021  False  MI         Wayne  None  None
# 1026        11       1994        2005   True  IL          Cook  None  None
# 1027         4       2001        2005   True  WI    Eau Claire  None  None
#
# [1028 rows x 13 columns]

# %%
# for each row, make a query for its ST and County into the counties df
for i,row in df.iterrows(): 
        query_string = f'state_id == "{row["ST"]}" and county == "{row["County"]}"'  # the " around the values are needed!
        
        try: # need to use try b/c the prisoner table has some States that don't exists (F-NY, etc.)
              cnty = df_counties.query(query_string)
              lat, long = float(cnty["lat"]), float(cnty["lng"])
        except:
              if row["ST"][0:2] == "F-":
                    row["ST"] = row["ST"][3:]
                    df.loc[i, "ST"] = row["ST"]  # remove F- in data
              
              state_row = df_states[df_states["postal_code"] == row["ST"]] # find row in state table
              state_row["lat"], state_row["lng"]
              df.loc[i, "Lat"] = lat 
              df.loc[i, "Long"] = long
        else:      
            df.loc[i, "Lat"] = lat 
            df.loc[i, "Long"] = long         
            #print(lat, long)

df
# Out:
#                        Name  Age   Race            Crime             Sentence  \
# #
# 0             Joseph Abbitt   31  Black  Child Sex Abuse                 Life
# 1        Warith Habib Abdal   43  Black   Sexual Assault           20 to Life
# 2     Christopher Abernathy   17  White           Murder  Life without parole
# 3             Quentin Abney   32  Black          Robbery           20 to Life
# 4             Don Ray Adams   32  Black           Murder                 Life
# ...                     ...  ...    ...              ...                  ...
# 1023       Anthony Yarbough   18  Black           Murder           75 to life
# 1024           Kenneth York   38  White   Sexual Assault  Life without parole
# 1025             Paul Young   17  Black           Murder  Life without parole
# 1026         Dan Young, Jr.   30  Black           Murder  Life without parole
# 1027         Evan Zimmerman   53  White           Murder                 Life
#
#       Duration  Convicted  Exonerated    DNA  ST        County      Lat  \
# #
# 0           14       1995        2009   True  NC       Forsyth  36.1306
# 1           16       1983        1999   True  NY          Erie   42.764
# 2           28       1987        2015   True  IL          Cook  41.8401
# 3            6       2006        2012  False  NY      New York  40.7785
# 4           19       1992        2011  False  PA  Philadelphia  40.0077
# ...        ...        ...         ...    ...  ..           ...      ...
# 1023        20       1994        2014   True  NY         Kings  40.6395
# 1024        16       1994        2010   True  MO        Vernon  37.8506
# 1025        34       1987        2021  False  MI         Wayne  42.2819
# 1026        11       1994        2005   True  IL          Cook  41.8401
# 1027         4       2001        2005   True  WI    Eau Claire  44.7268
#
#          Long
# #
# 0    -80.2563
# 1    -78.7323
# 2    -87.8168
# 3    -73.9674
# 4    -75.1339
# ...       ...
# 1023 -73.9385
# 1024 -94.3424
# 1025 -83.2822
# 1026 -87.8168
# 1027  -91.286
#
# [1028 rows x 13 columns]

# %%
# Save to new file
df.to_csv("filtered_with_latlong.csv")

# %%
# Run the graphing app inside jupyter

# Import packages
from dash import Dash, html, dash_table, dcc, callback, Output, Input
import pandas as pd
import plotly.express as px

# Incorporate data
df = pd.read_csv('filtered.csv')
num_rows = len(df)

# Initialize the app
app = Dash(__name__)

# App layout
app.layout = html.Div([
    html.Div(children=f'Total of {num_rows} entries, select a Histogram ',  style={'color': 'Gold', 'font-size': 20}),
    html.Hr(),

    
    dcc.RadioItems(options=['Race', 'Crime', 'ST', 'Age', 'Duration', 'DNA' ], value='Race', 
                   inline=True, 
                   id='controls-and-radio-item',
                   style={'color': 'Gold', 'font-size': 20}),
    dcc.Graph(figure={}, id='controls-and-graph')
])

# Add controls to build the interaction
@callback(
    Output(component_id='controls-and-graph', component_property='figure'),
    Input(component_id='controls-and-radio-item', component_property='value')
)


def update_graph(col_chosen):
    fig = px.histogram(df, x=col_chosen)
    return fig

def updateTable(n):
     pass

# Run the app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
